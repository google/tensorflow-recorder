# %% [markdown]
# # Convert image directory to TFRecord files

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import pathlib
import requests
import shutil
import tempfile

import pandas as pd
import tensorflow as tf
import tfrecorder

# %% [markdown]
# ## Convert sample image directory

# %%
image_dir = pathlib.Path(os.getcwd())/'../tfrecorder/test_data/images'
assert image_dir.exists()

# %%
output_dir = pathlib.Path('/tmp/tfrecords')
if output_dir.exists():
  
results = tfrecorder.create_tfrecords(str(image_dir), output_dir)
print(results)
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-10-0fdf3033e844> in <module>
#       1 output_dir = pathlib.Path('./tfrecords')
# ----> 2 results = tfrecorder.create_tfrecords(str(image_dir), output_dir)
#       3 print(results)
#
# ~/src/tfrecorder/tfrecorder/client.py in create_tfrecords(source, output_dir, schema, header, names, runner, project, region, tfrecorder_wheel, dataflow_options, job_label, compression, num_shards)
#     303   )
#     304
# --> 305   result = p.run()
#     306
#     307   if runner == 'DirectRunner':
#
# ~/envs/tfrecorder/lib/python3.6/site-packages/apache_beam/pipeline.py in run(self, test_runner_api)
#     529         tmpdir = tempfile.mkdtemp()
#     530         try:
# --> 531           pickler.dump_session(os.path.join(tmpdir, 'main_session.pickle'))
#     532         finally:
#     533           shutil.rmtree(tmpdir)
#
# ~/envs/tfrecorder/lib/python3.6/site-packages/apache_beam/internal/pickler.py in dump_session(file_path)
#     298   """
#     299   with _pickle_lock_unless_py2:
# --> 300     dill.dump_session(file_path)
#     301     dill.load_session(file_path)
#     302     return dill.dump_session(file_path)
#
# ~/envs/tfrecorder/lib/python3.6/site-packages/dill/_dill.py in dump_session(filename, main, byref, **kwds)
#     349         pickler._recurse = False # disable pickling recursion for globals
#     350         pickler._session = True  # is best indicator of when pickling a session
# --> 351         pickler.dump(main)
#     352     finally:
#     353         if f is not filename:  # If newly opened file
#
# ~/envs/tfrecorder/lib/python3.6/site-packages/dill/_dill.py in dump(self, obj)
#     443             raise PicklingError(msg)
#     444         else:
# --> 445             StockPickler.dump(self, obj)
#     446         stack.clear()  # clear record of 'recursion-sensitive' pickled objects
#     447         return
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in dump(self, obj)
#     407         if self.proto >= 4:
#     408             self.framer.start_framing()
# --> 409         self.save(obj)
#     410         self.write(STOP)
#     411         self.framer.end_framing()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# ~/envs/tfrecorder/lib/python3.6/site-packages/apache_beam/internal/pickler.py in save_module(pickler, obj)
#     170   def save_module(pickler, obj):
#     171     if dill.dill.is_dill(pickler) and obj is pickler._main:
# --> 172       return old_save_module(pickler, obj)
#     173     else:
#     174       dill.dill.log.info('M2: %s' % obj)
#
# ~/envs/tfrecorder/lib/python3.6/site-packages/dill/_dill.py in save_module(pickler, obj)
#    1293                 + ["__builtins__", "__loader__"]]
#    1294             pickler.save_reduce(_import_module, (obj.__name__,), obj=obj,
# -> 1295                                 state=_main_dict)
#    1296             log.info("# M1")
#    1297         else:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     632
#     633         if state is not None:
# --> 634             save(state)
#     635             write(BUILD)
#     636
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# ~/envs/tfrecorder/lib/python3.6/site-packages/apache_beam/internal/pickler.py in new_save_module_dict(pickler, obj)
#     218         return old_save_module_dict(pickler, obj)
#     219     else:
# --> 220       return old_save_module_dict(pickler, obj)
#     221
#     222   dill.dill.save_module_dict = new_save_module_dict
#
# ~/envs/tfrecorder/lib/python3.6/site-packages/dill/_dill.py in save_module_dict(pickler, obj)
#     910             # we only care about session the first pass thru
#     911             pickler._session = False
# --> 912         StockPickler.save_dict(pickler, obj)
#     913         log.info("# D2")
#     914     return
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save_dict(self, obj)
#     819
#     820         self.memoize(obj)
# --> 821         self._batch_setitems(obj.items())
#     822
#     823     dispatch[dict] = save_dict
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in _batch_setitems(self, items)
#     845                 for k, v in tmp:
#     846                     save(k)
# --> 847                     save(v)
#     848                 write(SETITEMS)
#     849             elif n:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# ~/envs/tfrecorder/lib/python3.6/site-packages/apache_beam/internal/pickler.py in new_save_module_dict(pickler, obj)
#     218         return old_save_module_dict(pickler, obj)
#     219     else:
# --> 220       return old_save_module_dict(pickler, obj)
#     221
#     222   dill.dill.save_module_dict = new_save_module_dict
#
# ~/envs/tfrecorder/lib/python3.6/site-packages/dill/_dill.py in save_module_dict(pickler, obj)
#     910             # we only care about session the first pass thru
#     911             pickler._session = False
# --> 912         StockPickler.save_dict(pickler, obj)
#     913         log.info("# D2")
#     914     return
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save_dict(self, obj)
#     819
#     820         self.memoize(obj)
# --> 821         self._batch_setitems(obj.items())
#     822
#     823     dispatch[dict] = save_dict
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in _batch_setitems(self, items)
#     845                 for k, v in tmp:
#     846                     save(k)
# --> 847                     save(v)
#     848                 write(SETITEMS)
#     849             elif n:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     519
#     520         # Save the reduce() output and finally memoize the object
# --> 521         self.save_reduce(obj=obj, *rv)
#     522
#     523     def persistent_id(self, obj):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     632
#     633         if state is not None:
# --> 634             save(state)
#     635             write(BUILD)
#     636
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# ~/envs/tfrecorder/lib/python3.6/site-packages/apache_beam/internal/pickler.py in new_save_module_dict(pickler, obj)
#     218         return old_save_module_dict(pickler, obj)
#     219     else:
# --> 220       return old_save_module_dict(pickler, obj)
#     221
#     222   dill.dill.save_module_dict = new_save_module_dict
#
# ~/envs/tfrecorder/lib/python3.6/site-packages/dill/_dill.py in save_module_dict(pickler, obj)
#     910             # we only care about session the first pass thru
#     911             pickler._session = False
# --> 912         StockPickler.save_dict(pickler, obj)
#     913         log.info("# D2")
#     914     return
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save_dict(self, obj)
#     819
#     820         self.memoize(obj)
# --> 821         self._batch_setitems(obj.items())
#     822
#     823     dispatch[dict] = save_dict
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in _batch_setitems(self, items)
#     845                 for k, v in tmp:
#     846                     save(k)
# --> 847                     save(v)
#     848                 write(SETITEMS)
#     849             elif n:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     519
#     520         # Save the reduce() output and finally memoize the object
# --> 521         self.save_reduce(obj=obj, *rv)
#     522
#     523     def persistent_id(self, obj):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     632
#     633         if state is not None:
# --> 634             save(state)
#     635             write(BUILD)
#     636
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# ~/envs/tfrecorder/lib/python3.6/site-packages/apache_beam/internal/pickler.py in new_save_module_dict(pickler, obj)
#     218         return old_save_module_dict(pickler, obj)
#     219     else:
# --> 220       return old_save_module_dict(pickler, obj)
#     221
#     222   dill.dill.save_module_dict = new_save_module_dict
#
# ~/envs/tfrecorder/lib/python3.6/site-packages/dill/_dill.py in save_module_dict(pickler, obj)
#     910             # we only care about session the first pass thru
#     911             pickler._session = False
# --> 912         StockPickler.save_dict(pickler, obj)
#     913         log.info("# D2")
#     914     return
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save_dict(self, obj)
#     819
#     820         self.memoize(obj)
# --> 821         self._batch_setitems(obj.items())
#     822
#     823     dispatch[dict] = save_dict
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in _batch_setitems(self, items)
#     845                 for k, v in tmp:
#     846                     save(k)
# --> 847                     save(v)
#     848                 write(SETITEMS)
#     849             elif n:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     519
#     520         # Save the reduce() output and finally memoize the object
# --> 521         self.save_reduce(obj=obj, *rv)
#     522
#     523     def persistent_id(self, obj):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     632
#     633         if state is not None:
# --> 634             save(state)
#     635             write(BUILD)
#     636
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# ~/envs/tfrecorder/lib/python3.6/site-packages/apache_beam/internal/pickler.py in new_save_module_dict(pickler, obj)
#     218         return old_save_module_dict(pickler, obj)
#     219     else:
# --> 220       return old_save_module_dict(pickler, obj)
#     221
#     222   dill.dill.save_module_dict = new_save_module_dict
#
# ~/envs/tfrecorder/lib/python3.6/site-packages/dill/_dill.py in save_module_dict(pickler, obj)
#     910             # we only care about session the first pass thru
#     911             pickler._session = False
# --> 912         StockPickler.save_dict(pickler, obj)
#     913         log.info("# D2")
#     914     return
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save_dict(self, obj)
#     819
#     820         self.memoize(obj)
# --> 821         self._batch_setitems(obj.items())
#     822
#     823     dispatch[dict] = save_dict
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in _batch_setitems(self, items)
#     845                 for k, v in tmp:
#     846                     save(k)
# --> 847                     save(v)
#     848                 write(SETITEMS)
#     849             elif n:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     494             reduce = getattr(obj, "__reduce_ex__", None)
#     495             if reduce is not None:
# --> 496                 rv = reduce(self.proto)
#     497             else:
#     498                 reduce = getattr(obj, "__reduce__", None)
#
# ~/envs/tfrecorder/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in __reduce__(self)
#     990
#     991   def __reduce__(self):
# --> 992     return convert_to_tensor, (self._numpy(),)
#     993
#     994   def __copy__(self):
#
# ~/envs/tfrecorder/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1029       return self._numpy_internal()
#    1030     except core._NotOkStatusException as e:  # pylint: disable=protected-access
# -> 1031       six.raise_from(core._status_to_exception(e.code, e.message), None)  # pylint: disable=protected-access
#    1032
#    1033   @property
#
# ~/envs/tfrecorder/lib/python3.6/site-packages/six.py in raise_from(value, from_value)
#
# InternalError: Tensorflow type 21 not convertible to numpy dtype.

# %% [markdown]
# ## Load a TF dataset from generated TFRecords

# %%
datasets = tfrecorder.load(results['tfrecord_dir'])

# %%
for x in datasets['TRAIN'].take(1):
  print(x.keys())
